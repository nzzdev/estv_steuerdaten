# %% [markdown]
# # Extract json

# %%
import json
from pathlib import Path
import pandas as pd
import utils

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Consts
export_folder = Path('../export/dumps/')

# %% [markdown]
# ## Import files

# %%
# Fill records, then create dataframe (faster than filling dfs directly)
records = []

for filename in list(export_folder.rglob('*.json')):
    
    data = json.load(open(filename, encoding='utf-8'))
    print("Load file %s" % filename)

    for pl in data['payload']:

        record = {
            'bfsId': pl['bfsId'],
            'municipality': pl['municipality'],
            'canton': pl['canton'],
            'cantonId': pl['cantonId'],
            'income': pl['income'],
            'massExportModelId': data['input']['massExportModelId'],
            'massExportModelText': utils.massExportModel[data['input']['massExportModelId']],
            'taxGroup': data['input']['taxGroup'],
            'confession': data['input']['confession'],
            'confessionText': utils.confessions[data['input']['confession']],
            'taxes': pl['values'][0]
        }

        # Loop years
        for i, year in enumerate(data['input']['years']):
            record['year'] = year

        records.append(record)
        
df = pd.DataFrame(records)
# Out:
# Load file ../export/dumps/5d1a72dee32b0e8a66a88a8906bc1dc600c48ea9.json
# Load file ../export/dumps/d9d85c3fa0fcf1ad1fa0d5aa1fa7c8938f8ad5f4.json
# Load file ../export/dumps/80fabfbf8b6bd161d1d38f21909eec8c18447770.json
# Load file ../export/dumps/581f0651aff451198fd810a60ce95c37807ff3a8.json
# Load file ../export/dumps/70019da08031dc32018c9bb9cdbc36ca0178c8dd.json
# Load file ../export/dumps/7d49a36c4bc65c636b4344d039d58b13281a1369.json
# Load file ../export/dumps/33d50eb8cdc3fb7ba2311ea5f0c38742be6e95c2.json
# Load file ../export/dumps/21d95ae70db97dab25c714a9da2b17f8b78544ff.json
# Load file ../export/dumps/b78079a03b9821b3e8c30026d0d07f5144dd6c8e.json
# Load file ../export/dumps/30964b4047a79cd3d9003283e73c605c5442e80e.json
# Load file ../export/dumps/43ab29d2d1fe54fe546380ef1e215a04e58583e7.json
# Load file ../export/dumps/00f6b71449208cb7094dc10fa6b33a8be490e8e3.json
# Load file ../export/dumps/56b75178c9bfead8621454833b30f10cc6ef0df3.json
# Load file ../export/dumps/22cdbdff092d367bb42edec631c60705954fa9cf.json
# Load file ../export/dumps/e80d4ff81107b2a53d38b605a720ee4b3365fef1.json
# Load file ../export/dumps/16c5779a9379392f9ac672e5f1c3502cc5c8481f.json
# Load file ../export/dumps/4467b07d545d8fa2beca2b81a6547a4e45e6fc1c.json
# Load file ../export/dumps/8fe46a59881d66fcc3c6a0ae9642e5159d7ee340.json
# Load file ../export/dumps/54f9b21403795595bc698200afc4e39e393e8916.json
# Load file ../export/dumps/8904b7c5e306bb36aa588617b80440d39444d13c.json
# Load file ../export/dumps/bc473fabf930e06b634d6ff1adcc421fb4d4385d.json
# Load file ../export/dumps/645f308173764a93071d15567d8a6794313b84cc.json
# Load file ../export/dumps/5ad4f27d95317c798b5a3787dd38dcb394ebab4f.json
# Load file ../export/dumps/f5d59d63193fdaa02b0d69963a39b7f3a36503f3.json
# Load file ../export/dumps/13898f7ff8555de394e52f4ba27af663467a6458.json
# Load file ../export/dumps/4e392e502646740bdb1c43d6c8435910d0d3166b.json
# Load file ../export/dumps/655a6e6ac4d1361123bab26008a8429013fc2b84.json
# Load file ../export/dumps/dcd6ff3f3f5b32834a0cca7e71fa798f40abe59e.json
# Load file ../export/dumps/407b94f3f085b8946de260667c9596739a791c58.json
# Load file ../export/dumps/d57124fba8926e89a3907bc16203515d4267a7af.json
# Load file ../export/dumps/c4570745b66870f3ce4b2d9cfb0356a14272361e.json
# Load file ../export/dumps/f5dd2399ab3d36997848ac9c8c94045c94871fd6.json
# Load file ../export/dumps/1194349ece48acccf5bb3b21693f49e3feaea90d.json
# Load file ../export/dumps/6a063b94a1d6475fb4df2367e84e694e9b4e05b4.json
# Load file ../export/dumps/4f022fd0740e8c92770252690d5bd0dba1cef787.json
# Load file ../export/dumps/30864076b2184779fb59b3340fade0b90ff16ddb.json
# Load file ../export/dumps/1dab797adb1888babc37e952e64c0cda4a7df67d.json
# Load file ../export/dumps/4b412b430ca0dbd177790ef4d03c8857805834a3.json
# Load file ../export/dumps/8fc66421591e225f911a7ad51ddfed25fee669ac.json
# Load file ../export/dumps/ec7956d16c01388087d2f1a00f655f5335a8b773.json
# Load file ../export/dumps/8df577d441e444539398f94eca9ba525e7d2b838.json
# Load file ../export/dumps/535c9a5072f8c45bcd1b0b61f9b50064900520a4.json
# Load file ../export/dumps/a7783b7261c3357f00e27ceed5aa79b0d24cf47a.json
# Load file ../export/dumps/c41c502b3f3bf0f0d6647fa261b6191daa359567.json
# Load file ../export/dumps/3dc45d15c36f26b24156a13aa89af7edc0b32d0b.json
# Load file ../export/dumps/a005713d8d7bd3d7d7c5c063ee38e87cd10f8a01.json
# Load file ../export/dumps/4f22c4d36ffaa87da6ad38bba6a7ce001f425f60.json
# Load file ../export/dumps/1c0a2e0eac5a36769b7f690dcb6ec181e303ff40.json
# Load file ../export/dumps/812333c28e67c8593f8f16108c579efaccd94ac3.json
# Load file ../export/dumps/50fe40d375d3cdcb25d2b2b9a1c51968348a0032.json
# Load file ../export/dumps/6af51b077a517addb80db5e407480e9a5dbbd3b2.json
# Load file ../export/dumps/54b5ae9177a521c2a4c07f89794a8bf993bd2bb6.json
# Load file ../export/dumps/0641ecff93916c2a92065a2c39b6500e49ce5159.json
# Load file ../export/dumps/e6f2a824f3fe6636e9219ccb489117fbe2902d94.json
# Load file ../export/dumps/c0551f13a3dfaec3cacef4a5412ad0e11ffa7f00.json
# Load file ../export/dumps/6a33faa43a58dd16d63146eb397c1cd8cc1160e1.json
# Load file ../export/dumps/316cb6acf0443b17723a79907e58c7c8ad48698d.json
# Load file ../export/dumps/f04fc7c80a7ba06ac6cee61760b3a55b8e8bee8e.json
# Load file ../export/dumps/eaaaa2267e70225371f70a4f5c6ed27a5eda8c61.json
# Load file ../export/dumps/13d3ee88dcae296e75bd83a636b646c46222f543.json
# Load file ../export/dumps/9eca3575a8de147d8551939560009ba338058135.json
# Load file ../export/dumps/01fb744b3a97de28833e1fcd48aad842f31c1225.json
# Load file ../export/dumps/d0f8269d4f90cc85332f789812fdcf4157fefb93.json
# Load file ../export/dumps/d69d777ad7708d79415aee0e5f12c7c469fe92cb.json
# Load file ../export/dumps/bf1b27402adf816f453da20e808179e89cc9afc7.json
# Load file ../export/dumps/96cf69f4433c7b3691146e93e773290f2e348478.json
# Load file ../export/dumps/0498e0b6fea462fe3a336a15335d37885fcaab76.json
# Load file ../export/dumps/f2d05c09da6e045cc3b2ab91cca082bb7c3ef425.json
# Load file ../export/dumps/da3b52a9f0bf0c03fc361cfbc9dd8dc8858c85a4.json
# Load file ../export/dumps/cfad4f5a58293581590a6a04beb275b3e4879eea.json
# Load file ../export/dumps/1a130b64cecb3782aa62796572eeed8275908fa8.json
# Load file ../export/dumps/e07e163ae56b89e0ee9a2c4990da2f5d0f2b14a6.json
# Load file ../export/dumps/8ab27c4c5faaa9b25f02f7c5e073215159b24e6c.json
# Load file ../export/dumps/47f91d901aedfa026b81a7eba9c49835311ca914.json
# Load file ../export/dumps/051525c4c7e0278169e629d96eb45c03951f195a.json
# Load file ../export/dumps/9907e7f47f14bf5365df2e5e79d47a4ae7dd5f5b.json
# Load file ../export/dumps/35fc3b3eedc3f31b99ea7ce7e1cc107f2c315a20.json
# Load file ../export/dumps/974291a84a77ef10412a1f514ed7fb466281950a.json
# Load file ../export/dumps/72667741948ecb34da8894ef1d4aceb7f60022f4.json
# Load file ../export/dumps/5ac7143d9e8858626f2f8664ff472a9239610b3a.json
# Load file ../export/dumps/3057657f226d2f7431c0385c7c83a4fc3040598f.json
# Load file ../export/dumps/845c4c5790205097fb89152657d8f556c60ff0a3.json
# Load file ../export/dumps/b247f759710d3fc145881d4f647d870e5fe3e675.json
# Load file ../export/dumps/23c124c57bffb39f28e141e69766d7f1bd466085.json
# Load file ../export/dumps/dbe7907452274273fb5a4eb06a9234b1274fb17c.json
# Load file ../export/dumps/ba0a74ff6cc8209d395e37ad29fd6ec6b5b117f1.json
# Load file ../export/dumps/bc339e3d6c572dd012e171a49786a76757f8cd21.json
# Load file ../export/dumps/1016cb9e159bc89479e5440d66c51942aac8e4c5.json
# Load file ../export/dumps/bacdcb7dbbb14fe57046557ffd2a0a939a001a29.json
# Load file ../export/dumps/1cd422a5491259cc2bab69885dfc031401c24acb.json
# Load file ../export/dumps/664d36b95b68b295ebb2c284ba63e93c8eddbead.json
# Load file ../export/dumps/c124ac73132547d4c5d05207a6d1689db2ef3cb5.json
# Load file ../export/dumps/8472308e79ada9535f470341a8a3018ec6cdc076.json
# Load file ../export/dumps/aba6b2eb9201928717c11ec254144462fc2f34fc.json
# Load file ../export/dumps/bf7443dca2b685b81860be4d3eb3fc9119d72b91.json
# Load file ../export/dumps/9f6f0a25b38ef531cd0c9576f81b8e9c1aa80aef.json
# Load file ../export/dumps/1ebf747fecc393ad8ecfacc6cde1b183675977f2.json
# Load file ../export/dumps/d199378cffb2d823161aa7f536d7d644727bc662.json
# Load file ../export/dumps/b637df0e6c2e7fd6cc2ea0188b835cc493887d5d.json
# Load file ../export/dumps/edff2196dcec5555a2983bb5c7ed9181cfd9e8c8.json
# Load file ../export/dumps/d1665c467bedb7335f8ab275655c0ae43bd1e239.json
# Load file ../export/dumps/41a423ac4ef88f48ba6b9555fbf85a4f6ef49d5b.json
# Load file ../export/dumps/20e387c563396c7ee59c647bfa7fed140039fa6e.json
# Load file ../export/dumps/10daff1606320f36470d940adda944bd8245d435.json
# Load file ../export/dumps/da216f9d609b8ccf601118f46a9f90045b43d302.json
# Load file ../export/dumps/d9218d8c6283eca59ed4c4795898f15b3461f4d3.json
# Load file ../export/dumps/1dc3a2a641edb5210815c1f3816850fcf17870fd.json
# Load file ../export/dumps/0d846960f960c15b3ee835843513b267aba09054.json
# Load file ../export/dumps/3a33f58f4701b5a19eaba637393fc7a8f19cfa7f.json
# Load file ../export/dumps/3e0603d714adf079d5cc16b92f20c663b011921e.json
# Load file ../export/dumps/ceccd06375c93ab34b3c75c4c3c3f7096b9a5d7d.json
# Load file ../export/dumps/1617cbaea91e6f7ada3264e709d8796398f49072.json
# Load file ../export/dumps/3e49d1cc4cc5486db386625f55f59925ac085462.json
# Load file ../export/dumps/3424f610004eb54f8e83a561a36108d846718ad9.json
# Load file ../export/dumps/1eb433bfbce53e81c3ffb0bdb8247a2dd11e9dc4.json
# Load file ../export/dumps/760648b8462e3d719d0a76b7c9857aaf2fff9d11.json
# Load file ../export/dumps/a130a2cb13400cb5585bfebfc4e46a4bbf873196.json
# Load file ../export/dumps/a7a4348286e0effe0918196bbd8c3159f2dd1098.json
# Load file ../export/dumps/2010c62ad2620a1a62d6e4bd7f54c3bfd1c06a4d.json
# Load file ../export/dumps/d85ab3e435f8653066e0ad0c2cb44615935b84cd.json
# Load file ../export/dumps/38462808c46c28b3f0e5a527bd3c0a0a65225549.json
# Load file ../export/dumps/1bb5fb8e9a2fb7056e2a16b7d288255f40c544d7.json
# Load file ../export/dumps/f5e702cf497d1bbb9324097841538cbcf8d6f3ac.json
# Load file ../export/dumps/aabf166c80398bb14f8a34db12a1115ad1c998f4.json
# Load file ../export/dumps/5e35279c2de72662605046959a82c4251b78b23d.json
# Load file ../export/dumps/b2720cb9aeb17dcb19073814bed635e106dbcc70.json
# Load file ../export/dumps/1730d9d744dcaff4f123fa80c6502e6e3742bb55.json
# Load file ../export/dumps/9619258af6cde8723f65e19445e138bc43a822d2.json
# Load file ../export/dumps/202e989b783e5d52be767b5e003ecc6bc62e057c.json
# Load file ../export/dumps/f08c1d68a3a417f19fbc783d915f3e7bd3ff1b90.json
# Load file ../export/dumps/c21e335938a61f1440f1ae67fd736c9f6f87a7d0.json
# Load file ../export/dumps/09c0f3702a28af87abf441c0ce3eda6efd79192d.json
# Load file ../export/dumps/e592c6e679fa2971e1ee9338d8f528714c23df67.json
# Load file ../export/dumps/79348ff4ce3147e2f4bbde45059ace2a4d48ad0c.json
# Load file ../export/dumps/38c9bcb055941ecfc7283640e1ed07159a63943c.json
# Load file ../export/dumps/de4d3614249f1e40a93b70a93eeafa4aec478b70.json
# Load file ../export/dumps/29e664d137bb10ae0425b38714b1d74966084659.json
# Load file ../export/dumps/866be10ae73b10a9f9a5cb5147f8c25933827f86.json
# Load file ../export/dumps/d5aacf986d2cd254d8a988fd35ffaf2f7bc58aae.json
# Load file ../export/dumps/1bb7e90e22ce0aba8781c04c739bc1fbaac49b7d.json
# Load file ../export/dumps/35f62300eddcbe558f27758dec2e15f468190957.json
# Load file ../export/dumps/617aaa08375e45374b7e8977b987605f49e8125e.json
# Load file ../export/dumps/dfe8b7e35571c54d4d1c61cb9994cd1e43dd9840.json
# Load file ../export/dumps/65e0a20cbe1d23fa0e222b007f5a6cd06b828391.json
# Load file ../export/dumps/1b3a0861e20741805a5ca5b0240c3d012bf35016.json
# Load file ../export/dumps/0841dc061b9b32127a237a90b798ff06fad57283.json
# Load file ../export/dumps/5b5209e7e87a41eec1f5032927a4fa267546bf2f.json
# Load file ../export/dumps/17dc5bea913e4a59b8090f26fec734fe05f24158.json
# Load file ../export/dumps/f709b466ca1d8def7a3d43ee0531af257b81ce9d.json
# Load file ../export/dumps/5b02fd6d3cea417448a8af8923066c729b538393.json
# Load file ../export/dumps/43c5f1dedb6babc72bf660c6dac40506a412f08a.json
# Load file ../export/dumps/17cf9930deebbf9ac5b74c47b354999a01284de5.json
# Load file ../export/dumps/4e3e6252be26549cc0a11585775f5190a4418ddd.json
# Load file ../export/dumps/411ea6aa237c47fb28ff9d3a10b211836970671b.json
# Load file ../export/dumps/1f56dfb2dc7bc71e3af76c98dd5146d567e1311d.json
# Load file ../export/dumps/528bbe402505c5386bc7f2f32e5abd3ed1b2f860.json
# Load file ../export/dumps/cad63298e059f6f42e747636a549f23a902accae.json
# Load file ../export/dumps/c658cf4b3956915d6fcc361ae4fcc65a2f19759b.json
# Load file ../export/dumps/fbf332128f0bc3373c8892455497cdd72052ee16.json
# Load file ../export/dumps/a3f884333747e02b951c6a35c9cdfccced7c2100.json
# Load file ../export/dumps/38d92a4c8c06d7308cee91f478fd1deda1443c0f.json
# Load file ../export/dumps/03165ba2e1b12e53b8205030885eb256b2363ab6.json
# Load file ../export/dumps/a7773c1e45fb4b57ab7990202a4e5324d661a21b.json
# Load file ../export/dumps/401e0e6ab627976a5dcb442127eeb61c914ab6a8.json
# Load file ../export/dumps/423ce1466fc6763fddd2819293f5b2fde160b86b.json
# Load file ../export/dumps/f059520a6a5ce7631c9dc1fda9a30313d48c9454.json
# Load file ../export/dumps/03cf2d20388c24b1b34e726eebcacbef0694b35c.json
# Load file ../export/dumps/133841fed28febae8106bc5e0ab9408f002a3824.json
# Load file ../export/dumps/8ad8d179c26458590c2599003820d63a20ffb628.json
# Load file ../export/dumps/bf39203403481372865bf5dd454b1542562b6052.json
# Load file ../export/dumps/58ab5df0960934a4171835435248829729fb7731.json
# Load file ../export/dumps/e56d597d1a6be38f18dccfeefd0bdbf13a799d39.json
# Load file ../export/dumps/3f95a3cae3ebde7e5b4c09ebefd11747a080a177.json
# Load file ../export/dumps/fe51b0d8bf634129344fc3a5b37534893ccf2d70.json
# Load file ../export/dumps/f3d05b6fd11dae52c3e1f407d077bfc501915847.json
# Load file ../export/dumps/3dced659d34115e9f63a77f737350bebc2829bf2.json
# Load file ../export/dumps/6ecf59777cdfa26c807a7409e7093b9f8f0d773a.json
# Load file ../export/dumps/f81c81a517444205ee50e7b5ce59031693f672bc.json
# Load file ../export/dumps/5fc74b8b56790ee149187e0c871a057c86fadf48.json
# Load file ../export/dumps/a034838930c65620565f3d739d62a86b58317392.json
# Load file ../export/dumps/75812075f9a5ebdb42b5e18aae7b216ca59ed07c.json
# Load file ../export/dumps/208a2aa530df8f1d98254b8de4da30ceb8db684b.json
# Load file ../export/dumps/5d18d59de4fec3764980ecfcb1025cb06ed98df0.json
# Load file ../export/dumps/4c8ad1f36b714823475ae5f9d0051933c16a88b3.json
# Load file ../export/dumps/dd51a225827262c6e20965f26d35567afd404c09.json
# Load file ../export/dumps/61d9c4a6d9b90cb5c785f17c75e31a4830942fa1.json
# Load file ../export/dumps/e10c25d448d8e79bb176cf74b156a746dc6ec0f1.json
# Load file ../export/dumps/5357807dfb7853b64a75e46008d3ce2b3b98511c.json
# Load file ../export/dumps/0120f1c99a700ab03b7f90bc75effb053b958866.json
# Load file ../export/dumps/19edecc7fd0fb0f5830ef8e529ac83da51d8e029.json
# Load file ../export/dumps/7ba5d019eb5371824d592869b7002af3b320fcbc.json
# Load file ../export/dumps/cd063c009a6a7755b30260a1935d791cf4daf5d8.json
# Load file ../export/dumps/142edbbc7cd01958e5405e3d05cecb731bdbd1e0.json
# Load file ../export/dumps/8b7ec40eb33d8f72650cc38e02614cb268b023cb.json
# Load file ../export/dumps/fecc18ed7005ac994c509eb3863ae8296c585190.json
# Load file ../export/dumps/55464e2d94331505541ba6d598e29fadebab11c4.json
# Load file ../export/dumps/21af6708d86d058702de01840a06e6c467824c9e.json
# Load file ../export/dumps/7b6e6279d960463e1e253f11d183f6e570faf5b9.json
# Load file ../export/dumps/5cccdfb0ca3e0a97e82c90882217fe1f44d3d64b.json
# Load file ../export/dumps/adc8ccec9a66cbb62cfb1c9ccd03539595aaf155.json
# Load file ../export/dumps/3ef473d309fc53a743be01b6ce3330b9b00e3cd6.json
# Load file ../export/dumps/3573fd6a182fd19007a0845719f7581a08d9da42.json
# Load file ../export/dumps/8af99f491de880ddb8273549a9e67a0876603791.json
# Load file ../export/dumps/35f4bca7a2ea74a213beae825addb2660aa7ad68.json
# Load file ../export/dumps/be48d63214c62f4a8f968d7ff330df78828112f2.json
# Load file ../export/dumps/7857875f84869a529f4fabb8763923d8e8b4bfae.json
# Load file ../export/dumps/4effa388834324987135da6693d8948a01b7632a.json
# Load file ../export/dumps/61aeb40cff86f95e7a76f6fce9c791df662610e9.json
# Load file ../export/dumps/8e4ce1b9e34a71097c42e72b55996a046389a821.json
# Load file ../export/dumps/319be53d293871cc57f84e3d12bac9a3e048c236.json
# Load file ../export/dumps/4e3df037499a0c461a9c56b7d36e9a7b5e534a1d.json
# Load file ../export/dumps/a0065a6a07865614c7e2123c19cefc8c2020cd35.json
# Load file ../export/dumps/83ba194dadd096ace3fbb38a11f6651530a38ddc.json
# Load file ../export/dumps/dd4aa625acaf347f4ff447ab68ad37b96eab1e6b.json
# Load file ../export/dumps/3cd6b7c28a5d795d57c16b639e2eb94ba87df08c.json
# Load file ../export/dumps/cf745b7d7da31c2ad0c8d67e91f9e8654d60d08a.json
# Load file ../export/dumps/7d7ef3cddeb2aec10b71964a6a7099860d6a9621.json
# Load file ../export/dumps/a9e4a5e6deebe2ad2da0e739df51fd8037a35cee.json
# Load file ../export/dumps/71d22149a700cbac408ccfb0d2ce099c91768f81.json
# Load file ../export/dumps/c0126cc912b48945aff79e099bf2adc424f18616.json
# Load file ../export/dumps/24cf941cdb6deeaf1bed5dbf301fa490aae006a2.json
# Load file ../export/dumps/9c8700ad2a6e4e31158d038d638e6ed70a46bf39.json
# Load file ../export/dumps/c6992227ad574ca97177d2e85e743f86a21f44ff.json
# Load file ../export/dumps/7e8242ae11116cbc1d81cf33c62861d74f52c443.json
# Load file ../export/dumps/38855d7dcc6ea61f6e85498fa5b77e58a580157e.json
# Load file ../export/dumps/c2d34222df92f69afc034a4faa07019e3e7412cb.json
# Load file ../export/dumps/8525095d557e96d5862267da0921916e15a367d8.json
# Load file ../export/dumps/77d68c243735b4385637c0481f1a5fb0b826ffe4.json
# Load file ../export/dumps/2836a10dcb7ed03c8bcb0b67636d3e7186e0c27e.json
# Load file ../export/dumps/2d387726284f80b765c8fff02aea6a22f53b9057.json
# Load file ../export/dumps/26f1439260ef0a144ff2fbd36cad5075c989dab0.json
# Load file ../export/dumps/eca45d2cc66793205543ed234b7f53ae95991adc.json
# Load file ../export/dumps/a7c17c4328bbfa79cf9c689fbfa171a653cfcd6f.json
# Load file ../export/dumps/10cf8b495d357b8e1d54c68416d23e62e6261543.json
# Load file ../export/dumps/3febd5792ede3becc511edfffec05b829594eb5f.json
# Load file ../export/dumps/b39638c44a83630b5931e5ad238f1bb5e7927f9c.json
# Load file ../export/dumps/de7666f0c6816f3819106025ebc29f41597f852c.json
# Load file ../export/dumps/779ef6716e2bffa489f5984e110998ebf6f48146.json
# Load file ../export/dumps/575d076dfd92f82296a0913f8bb521cbb7a71388.json
# Load file ../export/dumps/5fe50031b766b9d6bfd199744ee0594c41e5b919.json
# Load file ../export/dumps/0e8d4b533a1f5ccd839ade91727b48749945afb4.json
# Load file ../export/dumps/5e53dad34c9a87f52eb09872431b016f6339008e.json
# Load file ../export/dumps/f142983a158591a0517f46cd3e1336e5fd5d1803.json
# Load file ../export/dumps/cd87614106c68b9cd2cbac6e123622adc322bda9.json
# Load file ../export/dumps/5f432ea733615ec0c69da54debccf08dab241bde.json
# Load file ../export/dumps/464e3ecf0108961397e2d30dca7193ddd31c6767.json
# Load file ../export/dumps/29eccb06fdb1a5ee4331786fd9b06c145338b1d3.json
# Load file ../export/dumps/f59c05ac43c387dc97de26b32bba6f5d9b30c9c4.json
# Load file ../export/dumps/198db63f46e346198bb3d890e68ddcdcb2ba1c36.json
# Load file ../export/dumps/6bbba875c96f5e9049aa3a243c600ad9d6f47e1d.json
# Load file ../export/dumps/ba8fd54bf631de164317bbc125d07433535c7673.json
# Load file ../export/dumps/19b754e1b7a72187f65e2b4a37c08eeec35ae911.json
# Load file ../export/dumps/d617a427b54f6dc5b8aed292ceb72af4ba9ffa9e.json
# Load file ../export/dumps/dc9eb75f12ea07ece0d0cc4f0dbb22f203b3f889.json
# Load file ../export/dumps/8d651c118818491d161db856b85f446884781753.json
# Load file ../export/dumps/f10793a1adc467d9553e88ab59195d9e525a2d6e.json
# Load file ../export/dumps/c8673d64ac9d4c35a7cbe8385d554b35da18498b.json
# Load file ../export/dumps/e4809caf445c8136a07e573361ce8dd7a132b623.json
# Load file ../export/dumps/bc8be45725d2c5621c3a805638231cf86e7f302a.json
# Load file ../export/dumps/29d891b51ffc1a43b5a17d1e980c1827735b3ddf.json
# Load file ../export/dumps/05b1aa1e9b00ac6e4a6f60708235ad0b04dd2169.json
# Load file ../export/dumps/df0134e8baa41ca81cb896297ce0c4bd171b569a.json
# Load file ../export/dumps/a6235d4546514d202c229f191a059744dba927c7.json
# Load file ../export/dumps/832371a468c0b7a08b3ac0fee2d61cb283dc349a.json
# Load file ../export/dumps/096c33f14e2da355725f9264f6fe103b304d9b48.json
# Load file ../export/dumps/7cb13befc783e6d9cc303b92169e983c8b06ed63.json
# Load file ../export/dumps/3c4fdeaa334828e1aeecb148491bd0efc1685c11.json
# Load file ../export/dumps/2ef563fb6275bd1f45ca95a15d5a575c61ed0c58.json
# Load file ../export/dumps/262ac6c032e556cd1b0ace64236d5416a4dbdfc1.json
# Load file ../export/dumps/03a41b71cdf17a16c13c1822f8cc83da0a6b4f1d.json
# Load file ../export/dumps/c66e4075e4d3bc3e4eaae3e7904642fc77cfd2eb.json
# Load file ../export/dumps/7582f488bf2ebd696a942872cc59c84e4df4b68a.json
# Load file ../export/dumps/032da7ce95f806f9c7ee46918f5bc70c8d93beab.json
# Load file ../export/dumps/cba667fab47f6a6622c28e82e8daf0197399476f.json
# Load file ../export/dumps/87e81d66bef9d2da4d8c5eb0d14ab7116080babd.json
# Load file ../export/dumps/f007d69062a4ef3842880851ff2b31e8b293a182.json
# Load file ../export/dumps/0e86cec747c3fd8b791978ef4d7c383f11175ed7.json
# Load file ../export/dumps/7e8c3700dc20bbeb5456ff4f7a1d2649b7be7296.json
# Load file ../export/dumps/38fb132aa27318d452b62f02d4225f5b5ac220ab.json
# Load file ../export/dumps/6b6de091e23da339145aedc3941142309157f263.json
# Load file ../export/dumps/598d81979ae4e5e0c13b3b6e2cfcc2fff62bfbf1.json
# Load file ../export/dumps/72686dec1fcfef930d7b1e06af3299e6591732ef.json
# Load file ../export/dumps/e31bfb07db561dd11b1938f785998f504a52bb6a.json
# Load file ../export/dumps/8e89c86c859812d410a73518e8ac64080b161f36.json
# Load file ../export/dumps/2c241fdbca9d378b0c2a09b6e0da890469138ce7.json
# Load file ../export/dumps/20aa34eb6d3093571fe40ca1218daa599b81bba0.json
# Load file ../export/dumps/11c1794d7e95f5342388cf53463b8a13260a9dc3.json
# Load file ../export/dumps/d3a0419b786fdfdd9caaab637edb9f136cdc254c.json
# Load file ../export/dumps/64effd7c35f1c6c72410b2ee629a2d10d17b9c51.json
# Load file ../export/dumps/e37287b90501396e91845fd10ff1cbb38d5e9464.json
# Load file ../export/dumps/3c52f59b23759f5610ba97a21360ce4965c74e59.json
# Load file ../export/dumps/39704f92979e0cdfba209a7b31a18de2df18afa7.json
# Load file ../export/dumps/950fde9b062d8475de53e70d4c099d7c5fd55131.json
# Load file ../export/dumps/5ea7091ce6978c2b104f7a1bd53a50cd4949afd9.json
# Load file ../export/dumps/907a1c1bc0953dabe06fbacf1dfbc1c05ef23a35.json
# Load file ../export/dumps/8fd84289ddb447e570bac183b7bd5af1b103b1c7.json
# Load file ../export/dumps/e6c4de0d152f9df0bdeb86eef255446918b11beb.json
# Load file ../export/dumps/6ca055db30469d9e8da41c4713b9f22b58598fa7.json
# Load file ../export/dumps/d2afba34a7968a4388e2f97ce4871ef29bc3692a.json
# Load file ../export/dumps/ba88b5e19bd2f7946da1db77c72ab2b7f29f476a.json
# Load file ../export/dumps/1dedabe329e1f8b58e36a6e8491b5ddb24c86cef.json
# Load file ../export/dumps/f6b94b1aa623671fb3b917e7c0ce0cab752c7a20.json
# Load file ../export/dumps/2c34db74cefd0e967b94646945a0de3336013999.json
# Load file ../export/dumps/cd08323009ec07494b0b1aae57e4a5355fd85676.json
# Load file ../export/dumps/46229d61a800515ffa9745b9f8cc25f7a3a550bf.json
# Load file ../export/dumps/1ae4aae5d4c45355d8b5ccd5354e6fe71bb09a7d.json
# Load file ../export/dumps/e724d5ad27f3ebac87689374de559e423adbccc9.json
# Load file ../export/dumps/9a5c0a7a86c8d590ed347d9cdf98ba128e4308bf.json
# Load file ../export/dumps/7d5ea5ce5139d81a6797b2b2cd09650c431136ff.json
# Load file ../export/dumps/28a6d05217b2eac25915e29f76a95b32b1bda458.json
# Load file ../export/dumps/7e606c13898db95e78b6b02b179005bc9a403ab7.json
# Load file ../export/dumps/325f8be366363a42c735acbc495251fa43066cac.json
# Load file ../export/dumps/7588fbcec701a02a541e84a5bd7704e699be2b1f.json
# Load file ../export/dumps/a6445aed24b47a757c5185aa27b491d1167ddeb1.json
# Load file ../export/dumps/1dc33b4f6fa25a5480cb56664332594c6efe8656.json
# Load file ../export/dumps/702514e9feac0edfe13b405b3b9db37970b820ba.json
# Load file ../export/dumps/a28fa1b8686d1ccbe27c725aa17a6a09f9b89591.json
# Load file ../export/dumps/0905e97e02882d6644dfe95e2187544f97c2577d.json

# %%
# only data for all municipalities (taxGroup == 99) and no confessions
df = df[(df.taxGroup == 99) & (df.confession == 5)]

# %%
# check if we have all years
sorted(df.year.unique().tolist())
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]

# %%
# check if we have all tax categories for each year. Must be 20.
for y in sorted(df.year.unique().tolist()):
    print(str(y) +":" + str(df[df.year == y][['massExportModelText']].drop_duplicates().count().values))
# Out:
# 2010:[20]
# 2011:[20]
# 2012:[20]
# 2013:[20]
# 2014:[20]
# 2015:[20]
# 2016:[20]
# 2017:[20]
# 2018:[20]
# 2019:[20]
# 2020:[20]
# 2021:[20]

# %%
df.groupby(['massExportModelId', 'massExportModelText']).size().reset_index(name = 'Freq')
# Out:
#     massExportModelId                                massExportModelText  \
# 0                   1                                 Ledig, ohne Kinder
# 1                   2                                  Ledig, mit 1 Kind
# 2                   3                               Ledig, mit 2 Kindern
# 3                   4                               Ledig, mit 3 Kindern
# 4                   5            Verheiratet, ein Einkommen, ohne Kinder
# 5                   6             Verheiratet, ein Einkommen, mit 1 Kind
# 6                   7          Verheiratet, ein Einkommen, mit 2 Kindern
# 7                   8          Verheiratet, ein Einkommen, mit 3 Kindern
# 8                   9   Verheiratet, zwei Einkommen (70/30), ohne Kinder
# 9                  10    Verheiratet, zwei Einkommen (70/30), mit 1 Kind
# 10                 11  Verheiratet, zwei Einkommen (70/30), mit 2 Kin...
# 11                 12  Verheiratet, zwei Einkommen (70/30), mit 3 Kin...
# 12                 13   Verheiratet, zwei Einkommen (50/50), ohne Kinder
# 13                 14    Verheiratet, zwei Einkommen (50/50), mit 1 Kind
# 14                 15  Verheiratet, zwei Einkommen (50/50), mit 2 Kin...
# 15                 16  Verheiratet, zwei Einkommen (50/50), mit 3 Kin...
# 16                 17                                  Rentner/in, ledig
# 17                 18                            Verheiratet, eine Rente
# 18                 19                   Verheiratet, zwei Renten (70/30)
# 19                 20                   Verheiratet, zwei Renten (50/50)
#
#       Freq
# 0   757134
# 1   757134
# 2   757134
# 3   757134
# 4   757134
# 5   757134
# 6   757134
# 7   757134
# 8   757134
# 9   757134
# 10  757134
# 11  757134
# 12  757134
# 13  757134
# 14  757134
# 15  757134
# 16  757134
# 17  757134
# 18  757134
# 19  757134

# %%
# save a dataframe in wide format for each category separately
for i in df.massExportModelId.unique().tolist():
    df_ = df[df.massExportModelId == i]
    df_ = df_[['bfsId', 'cantonId', 'income', 'year', 'taxes']]
    df_.to_csv('/Users/florianseliger/NZZ-Mediengruppe/NZZ Visuals - Dokumente/Projekte/_2020/2021 Steuerbelastung Gemeinden/Daten/Neue_Daten/' + str(i) + '.csv', index = False)

# %%
df.head()
# Out:
#    bfsId municipality canton  cantonId   income  massExportModelId  \
# 0     21      Adlikon     ZH         1  15000.0                 17
# 1     21      Adlikon     ZH         1  20000.0                 17
# 2     21      Adlikon     ZH         1  25000.0                 17
# 3     21      Adlikon     ZH         1  30000.0                 17
# 4     21      Adlikon     ZH         1  35000.0                 17
#
#   massExportModelText  taxGroup  confession confessionText   taxes  year
# 0   Rentner/in, ledig        99           5         Andere   222.0  2016
# 1   Rentner/in, ledig        99           5         Andere   553.0  2016
# 2   Rentner/in, ledig        99           5         Andere  1064.0  2016
# 3   Rentner/in, ledig        99           5         Andere  1606.0  2016
# 4   Rentner/in, ledig        99           5         Andere  2208.0  2016
